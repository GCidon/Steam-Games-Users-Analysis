# %%
import csv
import pandas
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pandas.read_csv('max_genres.csv')

plt.style.use('ggplot')

x = df[df.columns[0]]
print(x)
y = df[df.columns[1]]
print(y)
x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, y, color='green')
#plt.xlabel("Energy Source")
plt.ylabel("Energy Output (GJ)")
#plt.title("Energy output from various fuel sources")

plt.xticks(x_pos, x)

plt.show()
# Out:
# 0      Dungeons & Dragons
# 1                   Otome
# 2        On-Rails Shooter
# 3               Benchmark
# 4                 Western
#               ...
# 338               Match 3
# 339            Illuminati
# 340           Competitive
# 341        Choices Matter
# 342               Violent
# Name: genre, Length: 343, dtype: object
# 0        2
# 1       39
# 2       10
# 3        4
# 4       23
#       ...
# 338    119
# 339      9
# 340     12
# 341     32
# 342    545
# Name: count, Length: 343, dtype: int64
